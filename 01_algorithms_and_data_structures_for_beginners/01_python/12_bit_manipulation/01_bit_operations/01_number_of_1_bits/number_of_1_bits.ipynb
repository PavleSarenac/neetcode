# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        numberOfOneBits = 0
        while n > 0:
            numberOfOneBits += n & 1
            n >>= 1
        return numberOfOneBits

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        res = 0
        for i in range(32):
            if (1 << i) & n:
                res += 1
        return res

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        res = 0
        while n:
            res += 1 if n & 1 else 0
            n >>= 1
        return res

# %% [markdown]
# ![](./drawings/number_of_1_bits_solution_03.svg)

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        res = 0
        while n:
            n &= n - 1
            res += 1
        return res

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        return bin(n).count('1')
